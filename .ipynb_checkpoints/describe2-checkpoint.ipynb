# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\NOUHAILA\PycharmProjects\QLSA\results\optimals.csv",sep=',')

# %%
'''df.groupby(["Problem","Algo"]).describe().to_csv("result.csv")'''
# Out:
# 'df.groupby(["Problem","Algo"]).describe().to_csv("result.csv")'

# %%
df.head()
# Out:
#    Problem  run                        Algo  Optimal
# 0     gr17    1         QL-SA_softmax_state   2123.0
# 1   bays29    1               QL-SA_softmax   2078.0
# 2  swiss42    2               QL-SA_softmax   1355.0
# 3   bays29    2                          SA   2190.0
# 4     hk48    1  Greedy_state_without_reset  12147.0

# %%
# Step 1: Group and aggregate
agg_df = df.groupby(['Problem','Algo']).agg(
    count_run=('run','count'),
    min_val=('Optimal','min'),
    max_val=('Optimal','max'),
    mean_val=('Optimal','mean'),
    std_val=('Optimal','std')
)

# Step 2: Stack the metrics and pivot
final_df = agg_df.stack().unstack('Algo')

# Optional: Rename the index for clarity
final_df = final_df.rename_axis(['Problem','Metric']).reset_index()

# Display
print(final_df)
# Out:
# Algo Problem     Metric       Greedy  Greedy_state  \
# 0     bayg29  count_run    10.000000     10.000000
# 1     bayg29    min_val  1645.000000   1638.000000
# 2     bayg29    max_val  1757.000000   1764.000000
# 3     bayg29   mean_val  1692.900000   1699.300000
# 4     bayg29    std_val    34.706548     39.757739
# 5     bays29  count_run    10.000000     10.000000
# 6     bays29    min_val  2089.000000   2028.000000
# 7     bays29    max_val  2242.000000   2318.000000
# 8     bays29   mean_val  2160.000000   2150.300000
# 9     bays29    std_val    44.524650     86.514032
#
# Algo  Greedy_state_without_reset  Greedy_without_reset  QL-SA_softmax  \
# 0                      10.000000             10.000000      10.000000
# 1                    1610.000000           1620.000000    1630.000000
# 2                    1658.000000           1716.000000    1741.000000
# 3                    1629.000000           1663.000000    1693.500000
# 4                      18.354533             32.530328      34.487518
# 5                      10.000000             10.000000      10.000000
# 6                    2020.000000           2035.000000    2055.000000
# 7                    2092.000000           2191.000000    2220.000000
# 8                    2050.000000           2096.100000    2132.500000
# 9                      19.425070             53.211214      49.900456
#
# Algo  QL-SA_softmax_state  QL-SA_softmax_state_without_reset  \
# 0               10.000000                          10.000000
# 1             1622.000000                        1610.000000
# 2             1772.000000                        1742.000000
# 3             1694.400000                        1657.000000
# 4               52.309336                          41.553179
# 5               10.000000                          10.000000
# 6             2026.000000                        2026.000000
# 7             2185.000000                        2131.000000
# 8             2098.400000                        2069.000000
# 9               57.436342                          34.035929
#
# Algo  QL-SA_softmax_without_reset           SA      Uniform
# 0                       10.000000    10.000000    10.000000
# 1                     1610.000000  1698.000000  1683.000000
# 2                     1679.000000  1930.000000  1962.000000
# 3                     1642.800000  1826.000000  1792.700000
# 4                       22.483574    74.700885    95.997743
# 5                       10.000000    10.000000    10.000000
# 6                     2020.000000  2107.000000  2020.000000
# 7                     2103.000000  2513.000000  2503.000000
# 8                     2062.100000  2335.800000  2183.600000
# 9                       28.384072   123.501507   160.696539

# %%
final_df.to_csv(r"C:\Users\NOUHAILA\PycharmProjects\QLSA\resultTransposed_04012026.csv")

# %%
# Set multi-index (Problem, Algo), stack metrics, then unstack Algo
reshaped = (
    df.set_index(["Problem", "Algo"])
      .stack()                # metrics become rows
      .reset_index()
      .rename(columns={"level_2": "Metric", 0: "Value"})
      .pivot_table(index=["Problem", "Metric"], columns="Algo", values="Value")
)

# Optional: reset index for a flat DataFrame
reshaped = reshaped.reset_index()

print(reshaped)
# Out:
# Algo Problem   Metric  Greedy  Greedy_state  Greedy_state_without_reset  \
# 0     bayg29  Optimal  1692.9        1699.3                      1629.0
# 1     bayg29      run     5.5           5.5                         5.5
# 2     bays29  Optimal  2160.0        2150.3                      2050.0
# 3     bays29      run     5.5           5.5                         5.5
#
# Algo  Greedy_without_reset  QL-SA_softmax  QL-SA_softmax_state  \
# 0                   1663.0         1693.5               1694.4
# 1                      5.5            5.5                  5.5
# 2                   2096.1         2132.5               2098.4
# 3                      5.5            5.5                  5.5
#
# Algo  QL-SA_softmax_state_without_reset  QL-SA_softmax_without_reset      SA  \
# 0                                1657.0                       1642.8  1826.0
# 1                                   5.5                          5.5     5.5
# 2                                2069.0                       2062.1  2335.8
# 3                                   5.5                          5.5     5.5
#
# Algo  Uniform
# 0      1792.7
# 1         5.5
# 2      2183.6
# 3         5.5

# %%
reshaped.to_csv(r"C:\Users\NOUHAILA\PycharmProjects\QLSA\resultTransposed_04012026_2.csv")
