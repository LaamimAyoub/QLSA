# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\NOUHAILA\PycharmProjects\QLSA\results\optimals.csv")

# %%
df.groupby(["Problem","Algo"]).describe().to_csv("result.csv")

# %%
df
# Out:
#     Problem  run                               Algo  Optimal
# 0    bays29    1                             Greedy   2141.0
# 1    bays29    2                       Greedy_state   2318.0
# 2    bayg29    1               Greedy_without_reset   1677.0
# 3    bays29    3                             Greedy   2227.0
# 4    bays29    1                       Greedy_state   2028.0
# ..      ...  ...                                ...      ...
# 195  bays29   10        QL-SA_softmax_without_reset   2062.0
# 196  bayg29   10                             Greedy   1691.0
# 197  bays29    9        QL-SA_softmax_without_reset   2077.0
# 198  bayg29   10                       Greedy_state   1741.0
# 199  bays29   10  QL-SA_softmax_state_without_reset   2026.0
#
# [200 rows x 4 columns]
